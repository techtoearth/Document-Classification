)
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())

for k,p in enumerate(windows_misc2.split('\n')):
    
    if k== 20000:
        break;
    documents[1].append( (p, "windows_misc") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())
    


for k,p in enumerate(electronics2.split('\n')):
    if k== 20000:
        break;
    documents[2].append( (p, "electronics") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:  
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())            
print(all_words)

save_documents = open("pickled_algos_mov/documents1.pickle","wb")
pickle.dump(documents, save_documents)
save_documents.close()
            
            
            
a=[]  
all_words_stop=[]
all_words1=[]
all_words2=[]

# filter starts

for i in all_words:
    if (i not in stop_words and i!='The' and i!='the'):
         all_words_stop.append(i)
            
for i in all_words_stop:
    if i.isalpha():
        all_words2.append(i)


for i in all_words2:
    all_words1.append(lemmatizer.lemmatize(i))

# filter ends
    
#print(type(documents))
all_words1= nltk.FreqDist(all_words1)

word_features = list(all_words1.keys())
#print(word_features)

save_word_features = open("pickled_algos_mov/word_features5k1.pickle","wb")
pickle.dump(word_features, save_word_features)
save_word_features.close()



cat=''
a=[]
lst=[]
freq=[{},{},{}]


#print('55555',freq[1],'55555')
word_features1=[]
for f in word_features:
        word_features1.append(f.lower())

#print(documents[1])
featuresets=[]
def extraction(i):
    a=[]
    no=""
    features={}
    freq={}
    global punctuations
    for char in i:
        if char in punctuations:
            no=no+' '+char
        else:
            no= no+ char
    no1=""
    for char in no:
        if char not in punctuations:
            no1=no1+char
        
    
    a = word_tokenize(no1)
    ak_stop=[]
    ak1=[]
    ak2=[]
    
    for s in a:
        if (s not in stop_words and s!='The' and s!='the'):
             ak_stop.append(s)
            
    for s in ak_stop:
        if s.isalpha():
            ak2.append(s)


    for s in ak2:
        ak1.append(lemmatizer.lemmatize(s))
    a1=[]
    for f in ak1:
        a1.append(f.lower())
 #   a=list(i.split(' '))
    features = {}
    
    counts = Counter(a1)
    #print("***counts")
    #print(type(counts))
    for i in counts:        
        freq[i]=counts[i]
       # print(i,freq[i]) 
   # print(a1,'999999999999999999999999999999999999999999999',end='\n\n\n\n')
    for w in word_features1:
        if((w in a1)==True):
            features[w]=freq[w]

        else:
            features[w]=0
    return features

for m in range(0,1):
    for k in l[m]:
        i=""
        i=open("20newsbydate/20news-bydate-test/sci.med/output/"+k,"r").read()        
        featuresets.append((extraction(i),documents[m][1][1]))

for m in range(1,2):
    for k in l[m]:
        i=""
        i=open("20newsbydate/20news-bydate-test/comp.os.ms-windows.misc/output/"+k,"r").read()        
        featuresets.append((extraction(i),documents[m][1][1]))
        
for m in range(2,3):
    for k in l[m]:
        i=""
        i=open("20newsbydate/20news-bydate-test/sci.electronics/output/"+k,"r").read()        
        featuresets.append((extraction(i),documents[m][1][1]))        
        
        
#print(documents[0][15])
#print(documents[0][10])
#print(documents[0][12])
#print('9999',featuresets[10],'9999')
#print('9999',featuresets[10],'9999')
    
    
random.shuffle(featuresets)
print(len(featuresets))



fset=open("pickled_algos_mov/featuresets1.pickle","wb")
pickle.dump(featuresets,fset)
fset.close()


testing_set = featuresets[820:]
training_set = featuresets[:820]
#print(type(testing_set))
#print('###',testing_set[1])
#print('###',training_set[1])


classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)
classifier.classify(featuresets[20])
###############

save_classifier = open("pickled_algos_mov/originalnaivebayes5k1.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)
classifier.show_most_informative_features(15)
classifier.classify(featuresets[20])
"""

save_classifier = open("pickled_algos_mov/MNB_classifier5k1.pickle","wb")
pickle.dump(MNB_classifier, save_classifier)
save_classifier.close()

BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/BernoulliNB_classifier5k1.pickle","wb")
pickle.dump(BernoulliNB_classifier, save_classifier)
save_classifier.close()

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/LogisticRegression_classifier5k1.pickle","wb")
pickle.dump(LogisticRegression_classifier, save_classifier)
save_classifier.close()


LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/LinearSVC_classifier5k1.pickle","wb")
pickle.dump(LinearSVC_classifier, save_classifier)
save_classifier.close()



SGDC_classifier = SklearnClassifier(SGDClassifier())
SGDC_classifier.train(training_set)
print("SGDClassifier accuracy percent:",nltk.classify.accuracy(SGDC_classifier, testing_set)*100)

save_classifier = open("pickled_algos_mov/SGDC_classifier5k1.pickle","wb")
pickle.dump(SGDC_classifier, save_classifier)
save_classifier.close()

voted_classifier=VoteClassifier(classifier,LinearSVC_classifier,MNB_classifier,BernoulliNB_classifier,LogisticRegression_classifier)

print("voted_classifier accuracy percent:",(nltk.classify.accuracy(voted_classifier,testing_set))*100)


def document(text):
    feats=extraction(text)
    
    return voted_classifier.classify(feats)
"""
# Out:
# ['banschbach', 'vms', 'ocom', 'okstate', 'edu', 're', 'candida', 'yeast', 'bloom', 'fact', 'fiction', 'lines', 'nntp', 'posting', 'host', 'vms', 'ocom', 'okstate', 'edu', 'organization', 'osu', 'college', 'osteopathic', 'medicine', 'article', 'hsdndev', 'harvard', 'edu', 'enterprise', 'bih', 'harvard', 'edu', 'david', 'rind', 'writes', 'article', 'vms', 'ocom', 'okstate', 'edu', 'banschbach', 'vms', 'ocom', 'okstate', 'edu', 'writes', 'poster', 'physician', 'disease', 'physician', 'quack', 'steve', 'others', 'quacks', 'quack', 'diagnoses', 'physician', 'enough', 'someone', 'quack', 'physician', 'quack', 'people', 't', 'can', 'example', 'ailment', 'quack', 'diagnosis', 'point', 'civilization', 'need', 'healers', 'advantage', 'people', 'david', 'rind', 't', 'term', 'quack', 'physician', 'david', 'conduct', 'opinion', 'examples', 'substances', 'patients', 'drug', 'addition', 'medication', 'preps', 'patients', 'thyroid', 'function', 'purpose', 'weight', 'loss', 'laetril', 'cancer', 'pati
# ...

# %%
)
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    if w[1][0] in allowed_word_types:
        all_words.append(w[0].lower())
            


for k,p in enumerate(windows_misc2.split('\n')):
    
    if k== 20000:
        break;
    documents[1].append( (p, "windows_misc") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())
    


for k,p in enumerate(electronics2.split('\n')):
    if k== 20000:
        break;
    documents[2].append( (p, "electronics") )
    words = word_tokenize(p)
    pos = nltk.pos_tag(words)
    for w in pos:
        if w[1][0] in allowed_word_types:
            all_words.append(w[0].lower())            
#print(documents)
#print(type(all_words))
#print(all_words)

save_documents = open("pickled_algos_mov/documents1.pickle","wb")
pickle.dump(documents, save_documents)
save_documents.close()
            
            
            
a=[]  
all_words_stop=[]
all_words1=[]
all_words2=[]

for i in all_words:
    if (i not in stop_words and i!='The' and i!='the'):
         all_words_stop.append(i)
            
for i in all_words_stop:
    if i.isalpha():
        all_words2.append(i)


for i in all_words2:
    all_words1.append(lemmatizer.lemmatize(i))

#print(type(documents))
all_words1= nltk.FreqDist(all_words1)
#print(all_words1.keys())
#print(all_words1.values())
word_features = list(all_words1.keys())
#print(type(word_features))
#print(word_features)

save_word_features = open("pickled_algos_mov/word_features5k1.pickle","wb")
pickle.dump(word_features, save_word_features)
save_word_features.close()



cat=''
a=[]
lst=[]
freq=[{},{},{}]


#print('55555',freq[1],'55555')
word_features1=[]
for f in word_features:
        word_features1.append(f.lower())

#print(documents[1])
featuresets=[]
def extraction(i):
    a=[]
    no=""
    features={}
    freq={}
    global punctuations
    for char in i:
        if char in punctuations:
            no=no+' '+char
        else:
            no= no+ char
    no1=""
    for char in no:
        if char not in punctuations:
            no1=no1+char
        
    
    a = word_tokenize(no1)
    ak_stop=[]
    ak1=[]
    ak2=[]
    
    for s in a:
        if (s not in stop_words and s!='The' and s!='the'):
             ak_stop.append(s)
            
    for s in ak_stop:
        if s.isalpha():
            ak2.append(s)


    for s in ak2:
        ak1.append(lemmatizer.lemmatize(s))
    a1=[]
    for f in ak1:
        a1.append(f.lower())
 #   a=list(i.split(' '))
    features = {}
    
    counts = Counter(a1)
   # print(type(counts))
    #print(counts)
    for i in counts: 
        freq[i]=counts[i]
   # print(a1,'999999999999999999999999999999999999999999999',end='\n\n\n\n')
    for w in word_features1:
        if((w in a1)==True):
            features[w]=freq[w]

        else:
            features[w]=0
    return features

for m in range(0,1):
    for k in l[m]:
        i=""
        i=open("20newsbydate/20news-bydate-test/sci.med/output/"+k,"r").read()        
        featuresets.append((extraction(i),documents[m][1][1]))
for m in range(1,2):
    for k in l[m]:
        i=""
        i=open("20newsbydate/20news-bydate-test/comp.os.ms-windows.misc/output/"+k,"r").read()        
        featuresets.append((extraction(i),documents[m][1][1]))
        
for m in range(2,3):
    for k in l[m]:
        i=""
        i=open("20newsbydate/20news-bydate-test/sci.electronics/output/"+k,"r").read()        
        featuresets.append((extraction(i),documents[m][1][1]))        
        
        
#print(documents[0][15])
#print(documents[0][10])
#print(documents[0][12])
#print(type(featuresets))
#print("******************************************")
#print('9999',featuresets[50],'9999')
#print('9999',featuresets[10],'9999')
    
    
random.shuffle(featuresets)
print(len(featuresets))



fset=open("pickled_algos_mov/featuresets1.pickle","wb")
pickle.dump(featuresets,fset)
fset.close()


testing_set = featuresets[820:]
training_set = featuresets[:820]
#print(type(testing_set))
#print('###',testing_set[1])
#print('###',training_set[1])


classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Original Naive Bayes Algo accuracy percent:", (nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)

###############
save_classifier = open("pickled_algos_mov/originalnaivebayes5k1.pickle","wb")
pickle.dump(classifier, save_classifier)
save_classifier.close()

MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MNB_classifier accuracy percent:", (nltk.classify.accuracy(MNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/MNB_classifier5k1.pickle","wb")
pickle.dump(MNB_classifier, save_classifier)
save_classifier.close()

BernoulliNB_classifier = SklearnClassifier(BernoulliNB())
BernoulliNB_classifier.train(training_set)
print("BernoulliNB_classifier accuracy percent:", (nltk.classify.accuracy(BernoulliNB_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/BernoulliNB_classifier5k1.pickle","wb")
pickle.dump(BernoulliNB_classifier, save_classifier)
save_classifier.close()

LogisticRegression_classifier = SklearnClassifier(LogisticRegression())
LogisticRegression_classifier.train(training_set)
print("LogisticRegression_classifier accuracy percent:", (nltk.classify.accuracy(LogisticRegression_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/LogisticRegression_classifier5k1.pickle","wb")
pickle.dump(LogisticRegression_classifier, save_classifier)
save_classifier.close()


LinearSVC_classifier = SklearnClassifier(LinearSVC())
LinearSVC_classifier.train(training_set)
print("LinearSVC_classifier accuracy percent:", (nltk.classify.accuracy(LinearSVC_classifier, testing_set))*100)

save_classifier = open("pickled_algos_mov/LinearSVC_classifier5k1.pickle","wb")
pickle.dump(LinearSVC_classifier, save_classifier)
save_classifier.close()



SGDC_classifier = SklearnClassifier(SGDClassifier())
SGDC_classifier.train(training_set)
print("SGDClassifier accuracy percent:",nltk.classify.accuracy(SGDC_classifier, testing_set)*100)

save_classifier = open("pickled_algos_mov/SGDC_classifier5k1.pickle","wb")
pickle.dump(SGDC_classifier, save_classifier)
save_classifier.close()

voted_classifier=VoteClassifier(classifier,LinearSVC_classifier,MNB_classifier,BernoulliNB_classifier,LogisticRegression_classifier)

print("voted_classifier accuracy percent:",(nltk.classify.accuracy(voted_classifier,testing_set))*100)


def document(text):
    feats=extraction(text)
    
    return voted_classifier.classify(feats)
# Out:
# 1183
# Original Naive Bayes Algo accuracy percent: 85.12396694214877
# Most Informative Features
#                     file = 1              window : medica =     28.0 : 1.0
#                 medicine = 1              medica : electr =     24.5 : 1.0
#                      med = 1              medica : electr =     22.5 : 1.0
#              electronics = 1              electr : medica =     22.2 : 1.0
#                      sci = 1              medica : window =     19.0 : 1.0
#                      ftp = 1              window : medica =     16.2 : 1.0
#                microsoft = 1              window : electr =     15.2 : 1.0
#                condition = 1              medica : window =     15.1 : 1.0
#                  circuit = 1              electr : medica =     14.2 : 1.0
#                    water = 1              medica : window =     13.8 : 1.0
#                   robert = 1              medica : window =     13.2 : 1.0
# ...
